# %%
# Vamos criar um modelo de regressão linear que converte C para F
import pandas as pd
data = pd.read_csv('temperatures.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   celcius     7 non-null      int64
#  1   fahrenheit  7 non-null      float64
# dtypes: float64(1), int64(1)
# memory usage: 244.0 bytes

# %%
data.head()
# Out:
#    celcius  fahrenheit
# 0      -40       -40.0
# 1      -10        14.0
# 2        0        32.0
# 3        8        46.4
# 4       15        59.0

# %%
import seaborn as sb

sb.scatterplot(x='celcius', y='fahrenheit', data=data, 
               hue='fahrenheit', 
               palette='coolwarm'
               )
# Out:
# <Axes: xlabel='celcius', ylabel='fahrenheit'>

# %%
X = data['celcius']
y = data['fahrenheit']

# %%
X
# Out:
# 0   -40
# 1   -10
# 2     0
# 3     8
# 4    15
# 5    22
# 6    38
# Name: celcius, dtype: int64

# %%
y
# Out:
# 0    -40.0
# 1     14.0
# 2     32.0
# 3     46.4
# 4     59.0
# 5     71.6
# 6    100.4
# Name: fahrenheit, dtype: float64

# %%
X_processed = X.values.reshape(-1, 1)

# %%
y_processed = y.values.reshape(-1, 1)

# %%
# Model creation

from sklearn.linear_model import LinearRegression

model = LinearRegression()

# %%
model.fit(X_processed, y_processed)
# Out:
# LinearRegression()

# %%
model.predict([[123]])
# Out:
# array([[253.4]])

# %%
model.score(X_processed, y_processed)
# Out:
# 1.0
